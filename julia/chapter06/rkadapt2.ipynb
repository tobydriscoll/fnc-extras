# %%
f = (u,t) -> (t+u)^2;

include("../FNC.jl")
t,u = FNC.rk23(f,[0,1],1.0,1e-5);
# Out:
# ┌ Warning: Stepsize too small near t=0.785408720407281
# └ @ Main.FNC /Users/driscoll/Dropbox/books/fnc-extras/julia/chapter06.jl:117

# %%
using Plots
plot(t,u,label="",
    xlabel="t",yaxis=(:log10,"u(t)"),title="Finite-time blowup")
